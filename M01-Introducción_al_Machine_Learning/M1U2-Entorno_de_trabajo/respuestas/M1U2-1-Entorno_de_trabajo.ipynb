# %% [markdown]
# # Entorno de trabajo
# M1U2 - Ejercicio 1
#
# ## Instalacion de Jupyter Notebook
#
# He instalado el entorno de trabajo Anaconda que incluye Jupyter Notebook.
#
# ## Instalacion de las Bibliotecas de Python
#
# ### pip
#
# ![image.png](attachment:4991458b-fb97-46aa-92dc-a31914cf0dd0.png)
#
# ### Instalacion de Numpy
#
# ![image.png](attachment:782c4b18-fc12-453e-9b54-584f9d4efbf0.png)
#
# ### Instalacion de Matplotlib
#
# ![image.png](attachment:66ee8c8d-c798-4fed-a429-1d50b1f36622.png)
#
# ### Instalacion de Scikit-learn
#
# ![image.png](attachment:d8d7fd24-fe4d-40c8-a73e-c1bf1d6efc9f.png)
#
# ### Instalacion de JupyterLab
#
# ![image.png](attachment:f9a83d7c-2f70-4949-bec2-91b177a7795f.png)
#
# [... ommited]
#
# ### JupyterLab
#
# ![image.png](attachment:2bb65c88-c428-4fd0-9c76-374753589738.png)
